# %% [markdown]
# # ✅ **TEST PRZEKROJOWY
#
# ---

# %% [markdown]
# ## **1. Jakiego typu będzie wynik operacji `3 / 2` w Pythonie 3?**

# %% [markdown]
# - A. `int`
# - B. `float`
# - C. `decimal.Decimal`
# - D. `Fraction`

# %%
82

# %% [markdown]
# # **2. Co wypisze kod?**
#
# ```python
# x = [1, 2, 3]
# y = x
# y.append(4)
# print(x)
# ```

# %% [markdown]
# - A. `[1, 2, 3]`
# - B. `[1, 2, 3, 4]`
# - C. `[4]`
# - D. Błąd

# %%
B 55%

# %% [markdown]
# ## **3. Co wypisze kod?**
#
# ```python
# for i in range(3):
#     pass
# print(i)
# ```

# %% [markdown]
# - A. błąd
# - B. `0`
# - C. `2`
# - D. `3`

# %%
45 C

# %% [markdown]
# ## **4. Co oznaczają `*args` w definicji funkcji?**

# %% [markdown]
# - A. argumenty domyślne
# - B. argumenty nazwane
# - C. dowolną liczbę argumentów pozycyjnych
# - D. listę argumentów

# %%
 64

# %% [markdown]
# ## **5. Co zwraca funkcja bez `return`?**

# %% [markdown]
# - A. `None`
# - B. `0`
# - C. pusty string
# - D. wyjątek

# %%
82 A

# %% [markdown]
# ## **6. Co wypisze kod?**
#
# ```python
# def f(a, b=2):
#     return a * b
#
# print(f(3))
# ```

# %% [markdown]
# - A. `6`
# - B. `None`
# - C. `TypeError`
# - D. `5`

# %%
91 A

# %% [markdown]
# ## **7. Co wypisze kod?**
#
# ```python
# items = [1, 2, 3]
# squares = [x * x for x in items]
# print(squares)
# ```

# %% [markdown]
# - A. `[1, 2, 3]`
# - B. `[1, 4, 9]`
# - C. `[1, 8, 27]`
# - D. błąd

# %%
91 B

# %% [markdown]
# ## **8. Czym jest generator w Pythonie?**

# %% [markdown]
# - A. funkcją zwracającą listę
# - B. funkcją używającą `yield` i zwracającą wartości leniwie
# - C. modułem
# - D. list comprehension

# %%
27 B

# %% [markdown]
# ## **9. Co robi operator `is`?**

# %% [markdown]
# - A. porównuje wartości
# - B. porównuje tożsamość obiektów
# - C. rzutuje na bool
# - D. łączy stringi

# %%
73 B

# %% [markdown]
# ## **10. Jak przechwycić wyjątek `ValueError`?**

# %% [markdown]
# - A. `except:`
# - B. `except ValueError:`
# - C. `catch ValueError:`
# - D. `except (ValueError as e):`

# %%
45 B

# %% [markdown]
# ## **11. Co wypisze kod?**

# %%
def make():
    x = 10
    def inner():
        return x
    x = 20
    return inner()

print(make())

# %% [markdown]
# - A. `10`
# - B. `20`
# - C. błąd
# - D. `None`

# %% [markdown]
# ## **12. Co wypisze kod?**
#
# ```python
#
# ```

# %%
def f(x, lst=[]):
    lst.append(x)
    return lst

print(f(1))
print(f(2))

# %% [markdown]
# - A. `[1]` i `[2]`
# - B. `[1]` i `[1,2]`
# - C. wyjątek
# - D. `[2]`, `[1]`

# %%
55 B

# %% [markdown]
# ## **13. Co wypisze kod?**
#
# ```python
# class A:
#     def __getattr__(self, name):
#         return 42
#
# a = A()
# print(a.foo)
# ```

# %% [markdown]
# - A. `AttributeError`
# - B. `None`
# - C. `42`
# - D. `TypeError`

# %%
18 C

# %% [markdown]
# ## **14. Co wypisze kod?**
#
# ```python
# a = (i for i in [1, 2, 3])
# b = (x * 2 for x in a)
# print(list(b))
# ```

# %% [markdown]
# - A. `[2, 4, 6]`
# - B. `[4, 8, 12]`
# - C. `[]`
# - D. `None`

# %%
91 A

# %% [markdown]
# ## **15. Jaki będzie wynik działania?**
#
# ```python
# class A:
#     value = 10
#
# class B(A):
#     value = 20
#
# a = A()
# b = B()
# print(a.value, b.value)
# ```

# %% [markdown]
# - A. `10 10`
# - B. `10 20`
# - C. `20 20`
# - D. `None`

# %%
73 B

# %% [markdown]
# ## **16. Co wypisze kod?**
#
# ```python
# def f():
#     return [lambda x: i * x for i in range(3)]
#
# funcs = f()
# print([fn(1) for fn in funcs])
# ```

# %%
def f():
    return [lambda x: i * x for i in range(3)]

funcs = f()
print([fn(1) for fn in funcs])
# Out:
# [2, 2, 2]

# %% [markdown]
# - A. `[0, 1, 2]`
# - B. `[2, 2, 2]`
# - C. `[0, 0, 0]`
# - D. `[3]`

# %%
9 B

# %% [markdown]
# ## **17. Która implementacja iteratora jest poprawna?**

# %% [markdown]
# A.
#
# ```python
# class It:
#     def __iter__(self):
#         return [1, 2, 3]
# ```
#
# B.
#
# ```python
# class It:
#     def __iter__(self):
#         return self
#     def __next__(self):
#         raise StopIteration
# ```
#
# C.
#
# ```python
# class It:
#     pass
# ```
#
# D.
#
# ```python
# class It:
#     def __next__(self):
#         return 1
# ```

# %%
36 B

# %% [markdown]
# ## **18. Co robi `functools.lru_cache()`?**

# %% [markdown]
# - A. usuwa duplikaty
# - B. cache’uje wyniki funkcji
# - C. loguje wywołania
# - D. zamyka zasoby

# %%
55 B

# %% [markdown]
# ## **19. Które stwierdzenie o GIL jest prawdziwe?**

# %% [markdown]
# - A. umożliwia równoległe wykonywanie kodu Python
# - B. blokuje równoległe wykonywanie kodu Python
# - C. nie istnieje do wersji 3.14
# - D. dotyczy tylko macOS

# %%
36 B

# %% [markdown]
# ## **20. Co wypisze kod?**
#
# ```python
# import threading
#
# counter = 0
#
# def add():
#     global counter
#     for _ in range(100000):
#         counter += 1
#
# threads = [threading.Thread(target=add) for _ in range(2)]
# [t.start() for t in threads]
# [t.join() for t in threads]
#
# print(counter)
# ```

# %%
import threading

counter = 0

def add():
    global counter
    for _ in range(100000):
        counter += 1

threads = [threading.Thread(target=add) for _ in range(2)]
[t.start() for t in threads]
[t.join() for t in threads]

print(counter)
# Out:
# 200000

# %% [markdown]
# - A. zawsze 200000
# - B. zawsze <200000
# - C. różne wyniki <=200000
# - D. To zależy na jakiej wersji Pythona

# %%
0 D   C

# %%
# %%writefile xxx.py
import threading

counter = 0

def add():
    global counter
    for _ in range(100000):
        counter += 1

threads = [threading.Thread(target=add) for _ in range(2)]
[t.start() for t in threads]
[t.join() for t in threads]

print(counter)
# Out:
# Overwriting xxx.py

# %%
# !uvx python@3.9 xxx.py
# Out:
# 174077

# %%
# !uvx python@3.10 xxx.py
# Out:
# 200000

# %%
# !uvx python@3.14 xxx.py
# Out:
# 200000

# %%
# !uvx python@3.14t xxx.py
# Out:
# 102670

# %% [markdown]
# # **21. Co wypisze kod?**
#
# ```python
# class A:
#     def __enter__(self):
#         print("in")
#         return 123
#     def __exit__(self, exc_type, exc, tb):
#         print("out")
#
# with A() as x:
#     print(x)
#
#
# ```

# %% [markdown]
# - A. `in 123 out`
# - B. `in`, potem `123`, potem `out`
# - C. `123`
# - D. błąd

# %% [markdown]
# 64%

# %% [markdown]
# ## **22. Co wypisze kod — descriptor?**
#
# ```python
# class Desc:
#     def __get__(self, instance, owner):
#         return 10
#
# class A:
#     x = Desc()
#
# a = A()
# print(a.x)
# ```

# %% [markdown]
# - A. błąd
# - B. `10`
# - C. `None`
# - D. `Desc()`

# %% [markdown]
# 58 B

# %% [markdown]
# ## **23a. Co wypisze kod?**
#
# ```python
# x = [1, 2]
# y = {x}
# print(x, y)
# ```

# %% [markdown]
# - A. `[1, 2] {[1, 2]}`
# - B. `[1, 2], {[1, 2]}`
# - C. błąd
# - D. `[1, 2] {1, 2}`

# %%
18C

# %% [markdown]
# ## **23b. Co wypisze kod?**
#
# ```python
# class A:
#     def __init__(self):
#         self.x = 1
#     def __repr__(self):
#         return str(self.x)
#
# a = A()
# s = {a}
# a.x = 2
# print(s)
# ```

# %% [markdown]
# - A. `{1}`
# - B. `{2}`
# - C. błąd
# - D. `{A(1)}`

# %% [markdown]
# 27B

# %% [markdown]
# ## **24. Co wypisze kod — argumenty domyślne?**
#
# ```python
# def append_to(element, target=[]):
#     target.append(element)
#     return target
#
# print(append_to(1))
# print(append_to(2))
# print(append_to(3, []))
# ```

# %% [markdown]
# - A. `[1]`, `[2]`, `[3]`
# - B. `[1]`, `[1,2]`, `[3]`
# - C. `[1,2]`, `[1,2,3]`, `[3]`
# - D. `[1]`, `[1]`, `[3]`

# %% [markdown]
# 64B

# %% [markdown]
# ## **25. Co robi poniższy kod?**
#
# ```python
# with open("file.txt") as f:
#     data = f.read()
# ```

# %% [markdown]
# - A. otwiera plik i nie zamyka
# - B. otwiera, odczytuje i zamyka
# - C. otwiera tylko do zapisu
# - D. wywołuje wyjątek

# %%
73 b

# %% [markdown]
# ### mid

# %% [markdown]
# ## **26. Co wypisze kod — MRO i wielodziedziczenie?**
#
# ```python
# class A:
#     def f(self): return "A"
#
# class B(A):
#     def f(self): return "B"
#
# class C(A):
#     def f(self): return "C"
#
# class D(B, C):
#     pass
#
# print(D().f())
# ```

# %% [markdown]
# - A. `A`
# - B. `B`
# - C. `C`
# - D. `TypeError`

# %%
0 B

# %% [markdown]
# ## **27. Co wypisze kod?**
#
# ```python
# class A:
#     pass
#
# a = A()
# setattr(a, "x", 10)
# print(a.x + getattr(a, "x"))
# ```

# %% [markdown]
# - A. `20`
# - B. `10`
# - C. `AttributeError`
# - D. `TypeError`

# %% [markdown]
# 20 A

# %% [markdown]
# ## **28. Co wypisze kod?**
#
# ```python
# class A:
#     @property
#     def x(self):
#         return 10
#
# class B(A):
#     x = 20
#
# print(B().x)
# ```

# %%
class A:
    @property
    def x(self):
        return 10

class B(A):
    x = 20

A().x
# Out:
# 10

# %% [markdown]
# - A. `10`
# - B. `20`
# - C. `None`
# - D. błąd

# %%
45 B

# %% [markdown]
# ## **29. Co wypisze kod — metaklasa?**
#
# ```python
# class Meta(type):
#     def __new__(cls, name, bases, attrs):
#         attrs["x"] = 99
#         return super().__new__(cls, name, bases, attrs)
#
# class A(metaclass=Meta):
#     pass
#
# print(A().x)
# ```

# %% [markdown]
# - A. `99`
# - B. `AttributeError`
# - C. `None`
# - D. błąd

# %%
36 A

# %% [markdown]
# ## **30. Co wypisze kod — generator delegujący (`yield from`)?**
#
# ```python
# def g():
#     yield from range(3)
#     yield 10
#
# print(list(g()))
# ```

# %% [markdown]
# - A. `[3, 10]`
# - B. `[0, 1, 2, 10]`
# - C. `[0, 1, 2]`
# - D. `[10]`

# %%
55 B

# %% [markdown]
# ## **31. Co wypisze kod — walidacja w descriptorze?**
#
# ```python
# class Positive:
#     def __set__(self, instance, value):
#         if value < 0:
#             raise ValueError
#         instance.__dict__["v"] = value
#     def __get__(self, instance, owner):
#         return instance.__dict__["v"]
#
# class A:
#     x = Positive()
#
# a = A()
# a.x = 5
# print(a.x)
# ```

# %% [markdown]
# - A. `5`
# - B. `ValueError`
# - C. `None`
# - D. `AttributeError`

# %% [markdown]
# 45A

# %% [markdown]
# ## **32. Co wypisze kod — override metody `__new__`?**
#
# ```python
# class A:
#     def __new__(cls):
#         print("new")
#         return super().__new__(cls)
#     def __init__(self):
#         print("init")
#
# A()
# ```

# %% [markdown]
# - A. `init new`
# - B. `new init`
# - C. tylko `new`
# - D. tylko `init`

# %% [markdown]
# 36 B

# %% [markdown]
# ## **33. Co wypisze kod — deepcopy vs shallow copy?**
#
# ```python
# import copy
#
# x = [1, [2, 3]]
# y = copy.copy(x)
# y[1].append(4)
# print(x)
# ```

# %%
import copy

x = [1, [2, 3]]
y = copy.copy(x) # [1, x[1]]
y[1].append(4)
print(x)
# Out:
# [1, [2, 3, 4]]

# %% [markdown]
# - A. `[1, [2, 3]]`
# - B. `[1, [2, 3, 4]]`
# - C. `[1, [4]]`
# - D. `[1, [2, 3, 4], [2,3]]`

# %% [markdown]
# 30B

# %% [markdown]
# ## **34. Co wypisze kod — asyncio i event loop?**
#
# ```python
# import asyncio
#
# async def f():
#     return 10
#
# result = asyncio.run(f())
# print(result)
# ```

# %% [markdown]
# - A. błąd (brak loopa)
# - B. `None`
# - C. `10`
# - D. `Future`

# %%
36 C

# %% [markdown]
# ## **35. Co wypisze kod — walidacja metodą `__set_name__` w descriptorze?**
#
# ```python
# class Prefix:
#     def __set_name__(self, owner, name):
#         self.name = "_" + name
#
#     def __set__(self, instance, value):
#         instance.__dict__[self.name] = value
#
#     def __get__(self, instance, owner):
#         return instance.__dict__[self.name]
#
# class A:
#     x = Prefix()
#
# a = A()
# a.x = 5
# print(a._x)
# ```

# %% [markdown]
# - A. `5`
# - B. `None`
# - C. `AttributeError`
# - D. `_x`

# %%
64 A

# %% [markdown]
# ## **36. Co wypisze kod — introspekcja na poziomie ramek wykonania (frame objects)?**
#
# ```python
# import inspect
#
# def f():
#     x = 10
#     frame = inspect.currentframe()
#     return frame.f_locals["x"]
#
# print(f())
# ```

# %% [markdown]
# - A. `10`
# - B. `None`
# - C. `NameError`
# - D. referencję do ramki

# %%
64 A

# %% [markdown]
# ## **37. Co wypisze kod — metaprogramowanie + dynamiczne dziedziczenie?**
#
# ```python
# def make_base(flag):
#     class Base:
#         def f(self): return "A"
#     class Base2:
#         def f(self): return "B"
#     return Base if flag else Base2
#
# class C(make_base(True)):
#     pass
#
# print(C().f())
# ```

# %% [markdown]
# - A. `A`
# - B. `B`
# - C. `None`
# - D. `TypeError`

# %%
70 A

# %% [markdown]
# ## **38. Co wypisze kod — złożone MRO z diamentem i mixinem?**
#
# ```python
# class X:
#     def f(self): return "X"
#
# class Y(X):
#     pass
#
# class Z(X):
#     def f(self): return "Z"
#
# class M:
#     def f(self): return "M"
#
# class A(Y, Z, M):
#     pass
#
# print(A().f())
# ```

# %%
class X:
    def f(self): return "X"

class Y(X):
    pass

class Z(X):
    def f(self): return "Z"

class M:
    def f(self): return "M"

class A(Y, Z, M):
    pass

print(A().f())
# Out:
# Z

# %%
A.mro()
# Out:
# [__main__.A, __main__.Y, __main__.Z, __main__.X, __main__.M, object]

# %% [markdown]
# - A. `X`
# - B. `Y`
# - C. `Z`
# - D. `M`

# %% [markdown]
# 27 C

# %% [markdown]
# ## **39. Co wypisze kod — asyncio task scheduling + event loop?**
#
# ```python
# import asyncio
#
# async def f():
#     await asyncio.sleep(0.1)
#     return 1
#
# async def g():
#     task = asyncio.create_task(f())
#     await asyncio.sleep(0.2)
#     return task.result()
#
# print(asyncio.run(g()))
# ```

# %% [markdown]
# - A. `1`
# - B. `None`
# - C. `Task pending`
# - D. `RuntimeError`

# %%
80 A

# %%
# %%writefile xxx.py
import asyncio

async def f():
    await asyncio.sleep(0.1)
    return 1

async def g():
    task = asyncio.create_task(f())
    await asyncio.sleep(0.2)
    return task.result()

print(asyncio.run(g()))
# Out:
# Overwriting xxx.py

# %%
# !python xxx.py
# Out:
# Traceback (most recent call last):
#   File "/Users/rkorzen/workspace/2025_11_18_kurs_python/xxx.py", line 12, in <module>
#     print(asyncio.run(g()))
#           ~~~~~~~~~~~^^^^^
#   File "/Users/rkorzen/.local/share/uv/python/cpython-3.14.0-macos-x86_64-none/lib/python3.14/asyncio/runners.py", line 204, in run
#     return runner.run(main)
#            ~~~~~~~~~~^^^^^^
#   File "/Users/rkorzen/.local/share/uv/python/cpython-3.14.0-macos-x86_64-none/lib/python3.14/asyncio/runners.py", line 127, in run
#     return self._loop.run_until_complete(task)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "/Users/rkorzen/.local/share/uv/python/cpython-3.14.0-macos-x86_64-none/lib/python3.14/asyncio/base_events.py", line 719, in run_until_complete
#     return future.result()
#            ~~~~~~~~~~~~~^^
#   File "/Users/rkorzen/workspace/2025_11_18_kurs_python/xxx.py", line 10, in g
#     return task.result()
#            ~~~~~~~~~~~^^
# ...

# %% [markdown]
# ## **40. Co zwróci kod — manualne tworzenie klasy przez `type()` i nadpisywanie `__call__`?**
#
# ```python
# def make():
#     def __call__(self, x):
#         return x * 3
#     return type("K", (), {"__call__": __call__})
#
# K = make()
# obj = K()
# print(obj(5))
# ```

# %% [markdown]
# - A. `5`
# - B. `15`
# - C. `TypeError`
# - D. `None`

# %% [markdown]
# 73 B
