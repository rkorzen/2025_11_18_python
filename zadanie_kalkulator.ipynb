# %%
# %%writefile kalkulator.py

def add(a, b):
    return a + b
# Out:
# Writing kalkulator.py

# %%
# %%writefile test_kalkulator.py

# import kalkulator

# kalkulator.add


from zadania.kalkulator import add

assert add(1, 2) == 3
# Out:
# Overwriting test_kalkulator.py

# %%
# !python test_kalkulator.py
# Out:
# Traceback (most recent call last):
#   File "/Users/rkorzen/workspace/2025_11_18_kurs_python/test_kalkulator.py", line 9, in <module>
#     assert add(1, 2) == 4
#            ^^^^^^^^^^^^^^
# AssertionError
